# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
raw_data = pd.read_csv('Movie.csv')
raw_data.head()
# Out:
#    Unnamed: 0 show_id   type         title             director  \
# 0           7      s8  Movie       Sankofa         Haile Gerima
# 1           9     s10  Movie  The Starling       Theodore Melfi
# 2          12     s13  Movie  Je Suis Karl  Christian Schwochow
# 3          24     s25  Movie         Jeans           S. Shankar
# 4          27     s28  Movie     Grown Ups         Dennis Dugan
#
#                                                 cast  \
# 0  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 2  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 3  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 4  Adam Sandler, Kevin James, Chris Rock, David S...
#
#                                              country          date_added  \
# 0  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 1                                      United States  September 24, 2021
# 2                            Germany, Czech Republic  September 23, 2021
# 3                                              India  September 21, 2021
# 4                                      United States  September 20, 2021
#
#    release_year rating duration  \
# 0          1993  TV-MA  125 min
# 1          2021  PG-13  104 min
# 2          2021  TV-MA  127 min
# 3          1998  TV-14  166 min
# 4          2010  PG-13  103 min
#
#                                           listed_in  \
# 0  Dramas, Independent Movies, International Movies
# 1                                  Comedies, Dramas
# 2                      Dramas, International Movies
# 3   Comedies, International Movies, Romantic Movies
# 4                                          Comedies
#
#                                          description
# 0  On a photo shoot in Ghana, an American model s...
# 1  A woman adjusting to life after a loss contend...
# 2  After most of her family is murdered in a terr...
# 3  When the father of the man she loves insists t...
# 4  Mourning the loss of their beloved junior high...

# %%
print(f'Dữ liệu Netflix có {raw_data.shape[1]} cột và {raw_data.shape[0]} dòng.')
# Out:
# Dữ liệu Netflix có 15 cột và 5277 dòng.

# %%
raw_data['date_added']=pd.to_datetime(raw_data['date_added'])
raw_data['year_added']=raw_data['date_added'].apply(lambda x: int(x.year))
raw_data['month_added']=raw_data['date_added'].apply(lambda x: int(x.month))

# %%
cast = pd.DataFrame(raw_data['cast'].apply(lambda x: str(x).split(', ')).tolist(),index=raw_data['show_id'])
cast=cast.stack().reset_index().drop('level_1',axis=1)
cast.rename(columns={0:'actor'},inplace=True)

# %%
director = pd.DataFrame(raw_data['director'].apply(lambda x: str(x).split(', ')).tolist(),index=raw_data['show_id'])
director=director.stack().reset_index().drop('level_1',axis=1)
director.rename(columns={0:'director'},inplace=True)

# %%
country = pd.DataFrame(raw_data['country'].apply(lambda x: str(x).split(', ')).tolist(),index=raw_data['show_id'])
country=country.stack().reset_index().drop('level_1',axis=1)
country.rename(columns={0:'country'},inplace=True)

# %%
genre = pd.DataFrame(raw_data['listed_in'].apply(lambda x: str(x).split(', ')).tolist(),index=raw_data['show_id'])
genre=genre.stack().reset_index().drop('level_1',axis=1)
genre.rename(columns={0:'genre'},inplace=True)

# %%
temp = cast.merge(director, on=['show_id'], how='inner')
temp1 = temp.merge(country, on=['show_id'], how='inner')
temp2 = temp1.merge(genre, on=['show_id'], how='inner')

# %%
data = temp2.merge(raw_data[['show_id','type','title','date_added','release_year','rating','duration',
                             'description','year_added','month_added']],
                             on='show_id',how='inner').iloc[:,[0,5,6,1,2,3,4,7,8,9,10,11,12,13]]

# %%
movies = data[data['type']=='Movie']
tv_shows = data[data['type']=='TV Show']
tv=tv_shows['duration'].apply(lambda x:int(str(x).split(' ')[0]))
tv_shows=tv_shows.drop('duration',axis=1)
tv_shows['seasons']=tv
tv_shows.head()
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, actor, director, country, genre, date_added, release_year, rating, description, year_added, month_added, seasons]
# Index: []

# %%
movie=movies['duration'].apply(lambda x:int(str(x).split(' ')[0]))
movies=movies.drop('duration',axis=1)
movies['duration']=movie
movies.head()
# Out:
#   show_id   type    title         actor      director        country  \
# 0      s8  Movie  Sankofa  Kofi Ghanaba  Haile Gerima  United States
# 1      s8  Movie  Sankofa  Kofi Ghanaba  Haile Gerima  United States
# 2      s8  Movie  Sankofa  Kofi Ghanaba  Haile Gerima  United States
# 3      s8  Movie  Sankofa  Kofi Ghanaba  Haile Gerima          Ghana
# 4      s8  Movie  Sankofa  Kofi Ghanaba  Haile Gerima          Ghana
#
#                   genre date_added  release_year rating  \
# 0                Dramas 2021-09-24          1993  TV-MA
# 1    Independent Movies 2021-09-24          1993  TV-MA
# 2  International Movies 2021-09-24          1993  TV-MA
# 3                Dramas 2021-09-24          1993  TV-MA
# 4    Independent Movies 2021-09-24          1993  TV-MA
#
#                                          description  year_added  month_added  \
# 0  On a photo shoot in Ghana, an American model s...        2021            9
# 1  On a photo shoot in Ghana, an American model s...        2021            9
# 2  On a photo shoot in Ghana, an American model s...        2021            9
# 3  On a photo shoot in Ghana, an American model s...        2021            9
# 4  On a photo shoot in Ghana, an American model s...        2021            9
#
#    duration
# 0       125
# 1       125
# 2       125
# 3       125
# 4       125

# %%
t = movies[(movies['type']!='Unknown')&(movies['director']!='Unknown')].groupby(['type','director']).agg(
    {'show_id':'nunique'}).reset_index().sort_values(
    'show_id',ascending=False).head(80)
t1=movies.merge(t,on=['type','director'],how='inner').groupby(['type','director']).agg(
    {'show_id_x':'nunique'}).reset_index().sort_values('show_id_x',ascending=False).head(15).rename(
    {'show_id_x':'Total Movies'},axis=1)
t1
# Out:
#      type             director  Total Movies
# 18  Movie            Jan Suter            21
# 53  Movie          Raúl Campos            19
# 20  Movie            Jay Karas            15
# 38  Movie         Marcus Raboy            14
# 6   Movie  Cathy Garcia-Molina            13
# 39  Movie      Martin Scorsese            12
# 77  Movie      Youssef Chahine            12
# 19  Movie          Jay Chapman            12
# 68  Movie     Steven Spielberg            11
# 12  Movie     Don Michael Paul            10
# 78  Movie       Yılmaz Erdoğan             9
# 8   Movie         David Dhawan             9
# 63  Movie      Shannon Hartman             9
# 71  Movie          Troy Miller             8
# 24  Movie       Justin G. Dyck             8

# %%
pd.options.display.max_colwidth = 200
title_and_cast_df = raw_data[['director','listed_in']]
title_and_cast_df = title_and_cast_df.dropna()
cast_names_counter = {}
for i, row in title_and_cast_df.iterrows():
    movie_cast = row['director']
    movie_cast_split = movie_cast.split(',')
    movie_cast_stripped = [name.strip() for name in movie_cast_split]
    for name in movie_cast_stripped:
        cast_names_counter[name] = cast_names_counter.get(name,0) + 1
dict(sorted(cast_names_counter.items(),key=lambda item:item[1], reverse = True))
# Out:
# {'Unknown': 92,
#  'Jan Suter': 21,
#  'Raúl Campos': 19,
#  'Jay Karas': 15,
#  'Marcus Raboy': 14,
#  'Cathy Garcia-Molina': 13,
#  'Youssef Chahine': 12,
#  'Martin Scorsese': 12,
#  'Jay Chapman': 12,
#  'Steven Spielberg': 11,
#  'Don Michael Paul': 10,
#  'David Dhawan': 9,
#  'Yılmaz Erdoğan': 9,
#  'Shannon Hartman': 9,
#  'Robert Rodriguez': 8,
#  'Hakan Algül': 8,
#  'Hanung Bramantyo': 8,
#  'Troy Miller': 8,
#  'Anurag Kashyap': 8,
#  'Justin G. Dyck': 8,
#  'Johnnie To': 8,
#  'Umesh Mehra': 8,
#  'Toshiya Shinohara': 7,
#  'Lasse Hallström': 7,
#  'Dibakar Banerjee': 7,
#  'Clint Eastwood': 7,
#  'Ram Gopal Varma': 7,
#  'Quentin Tarantino': 7,
#  'McG': 7,
#  'Ron Howard': 7,
#  'Leslie Small': 7,
#  'Kunle Afolayan': 7,
#  'Lance Bangs': 7,
#  'Noah Baumbach': 7,
#  'Ryan Polito': 7,
#  'Robert Luketic': 6,
#  'Steve Brill': 6,
#  'David Fincher': 6,
#  'Kevin Smith': 6,
#  'Ozan Açıktan': 6,
#  'Ashutosh Gowariker': 6,
#  'Mae Czarina Cruz': 6,
#  'Fernando Ayllón': 6,
#  'Rajkumar Santoshi': 6,
#  'Imtiaz Ali': 6,
#  'Anees Bazmee': 6,
#  'Jesse V. Johnson': 6,
#  'Karan Johar': 6,
#  'Zoya Akhtar': 6,
#  'Sooraj R. Barjatya': 6,
#  'Sameh Abdulaziz': 6,
#  'Steven Soderbergh': 6,
#  'Rocky Soraya': 6,
#  'Robert Vince': 6,
#  'Priyadarshan': 6,
#  'Wong Jing': 6,
#  'Riri Riza': 6,
#  'Masahiko Murata': 5,
#  'Spike Lee': 5,
#  'Martin Campbell': 5,
#  'Anurag Basu': 5,
#  'Milan Luthria': 5,
#  'Vince Marcello': 5,
#  'Rohit Shetty': 5,
#  'Paul Thomas Anderson': 5,
#  'Jay Roach': 5,
#  'Lynn Shelton': 5,
#  'John G. Avildsen': 5,
#  'Antoinette Jadaone': 5,
#  'Andy Tennant': 5,
#  'Kıvanç Baruönü': 5,
#  'Angga Dwimas Sasongko': 5,
#  'Manny Rodriguez': 5,
#  'Prakash Jha': 5,
#  'Detlev Buck': 5,
#  'Indra Kumar': 5,
#  'Mahesh Manjrekar': 5,
#  'Khaled Marei': 5,
#  'Niyi Akinmolayan': 5,
#  'Wilson Yip': 5,
#  'Abbas Alibhai Burmawalla': 5,
#  'Mastan Alibhai Burmawalla': 5,
#  'Omoni Oboli': 5,
#  'Michael Simon': 5,
#  'Wenn V. Deramas': 5,
#  'Matt Askem': 5,
#  'Madhur Bhandarkar': 5,
#  'Vishal Bhardwaj': 5,
#  'Ishi Rudell': 5,
#  'Mike Clattenburg': 5,
#  'Rajiv Mehra': 5,
#  'Thierry Donard': 5,
#  'William Lau': 5,
#  'Lilly Wachowski': 5,
#  'Lana Wachowski': 5,
#  'Dennis Dugan': 4,
#  'Antoine Fuqua': 4,
#  'Raja Gosnell': 4,
#  'Nagesh Kukunoor': 4,
#  'Peter Farrelly': 4,
#  'Mani Ratnam': 4,
#  'Kayode Kasum': 4,
#  'Brian Levant': 4,
#  'Clay Glen': 4,
#  'Rajiv Chilaka': 4,
#  'Ernie Barbarash': 4,
#  'Rob Minkoff': 4,
#  'Cristina Jacob': 4,
#  'Mike Gunther': 4,
#  'Michael Tiddes': 4,
#  'Rob Reiner': 4,
#  'Bo Burnham': 4,
#  'Sean McNamara': 4,
#  'Roger Kumble': 4,
#  'Oliver Stone': 4,
#  'Fajar Bustomi': 4,
#  'Ava DuVernay': 4,
#  'Jun Lana': 4,
#  'Shaun Paul Piccinino': 4,
#  'Shyam Benegal': 4,
#  'Dan Villegas': 4,
#  'Maroun Baghdadi': 4,
#  'Philippe Aractingi': 4,
#  'Sam Liu': 4,
#  'Sudhir Mishra': 4,
#  'Shigeaki Kubo': 4,
#  'Antonio Campos': 4,
#  'Ahmed Nader Galal': 4,
#  'Conrad Helten': 4,
#  'Savage Steve Holland': 4,
#  'Steve Ball': 4,
#  'Fernando González Molina': 4,
#  'Nishikant Kamat': 4,
#  'Wael Ehsan': 4,
#  'Wael Ihsan': 4,
#  'Farhan Akhtar': 4,
#  'Vlad Yudin': 4,
#  'Rakeysh Omprakash Mehra': 4,
#  'Terry Gilliam': 4,
#  'Rohit Jugraj': 4,
#  'Jeremy Saulnier': 4,
#  'Qaushiq Mukherjee': 4,
#  'Mike Newell': 4,
#  'Farah Khan': 4,
#  'Mike Smith': 4,
#  'John Paul Tremblay': 4,
#  'Robb Wells': 4,
#  'Kundan Shah': 4,
#  'Lee Tamahori': 4,
#  'Hrishikesh Mukherjee': 4,
#  'Chris Stokes': 4,
#  'Gregory Hoblit': 4,
#  'Steve Carr': 4,
#  'Chia-Liang Liu': 4,
#  'Subhash Ghai': 4,
#  'Poj Arnon': 4,
#  'Banjong Pisanthanakun': 4,
#  'Scott Stewart': 3,
#  'Jane Campion': 3,
#  'Phillip Noyce': 3,
#  'Renny Harlin': 3,
#  'Simon Wincer': 3,
#  'Sebastián Schindel': 3,
#  'Steven C. Miller': 3,
#  'Reginald Hudlin': 3,
#  'Pang Ho-cheung': 3,
#  'Tim Burton': 3,
#  'David Zucker': 3,
#  'Bobby Farrelly': 3,
#  'Wolfgang Petersen': 3,
#  'Sachin Yardi': 3,
#  'Roger Donaldson': 3,
#  'Drake Doremus': 3,
#  'Adze Ugah': 3,
#  'Robert Zemeckis': 3,
#  'Brad Anderson': 3,
#  'Garry Marshall': 3,
#  'Sofia Coppola': 3,
#  'Chris Weitz': 3,
#  'Chris Buck': 3,
#  'Barry Levinson': 3,
#  'Rano Karno': 3,
#  'Paul W.S. Anderson': 3,
#  'Ivan Reitman': 3,
#  'Gabriele Muccino': 3,
#  'Adam McKay': 3,
#  'Walter Hill': 3,
#  'Paul Weitz': 3,
#  'Mark Raso': 3,
#  'Alex Díaz': 3,
#  'Les Mayfield': 3,
#  'Andrzej Bartkowiak': 3,
#  'Ric Roman Waugh': 3,
#  'Todd Phillips': 3,
#  'David Ayer': 3,
#  'Paul Greengrass': 3,
#  'Eric Darnell': 3,
#  'Roland Emmerich': 3,
#  'Peter Jackson': 3,
#  'Ömer Faruk Sorak': 3,
#  'Alexis Morante': 3,
#  'Burak Aksak': 3,
#  'Bedran Güzel': 3,
#  'Abhinay Deo': 3,
#  'Guillermo del Toro': 3,
#  'Rajkumar Hirani': 3,
#  'James Wan': 3,
#  'Peyton Reed': 3,
#  'Blair Simmons': 3,
#  'Tate Taylor': 3,
#  'Andrew Duncan': 3,
#  'Pablo Larraín': 3,
#  'Ribhu Dasgupta': 3,
#  'Florent Bodin': 3,
#  'Richard Weston': 3,
#  'Vikramaditya Motwane': 3,
#  'Andibachtiar Yusuf': 3,
#  'Paul Dugdale': 3,
#  'Yasmin Ahmad': 3,
#  'Theodore Boborol': 3,
#  'Greg Rankin': 3,
#  'TJ Sullivan': 3,
#  'Jeff Nichols': 3,
#  'Tope Oshin': 3,
#  'Ken Ghosh': 3,
#  'Christopher Nolen': 3,
#  'Adrian Teh': 3,
#  'Abhishek Chaubey': 3,
#  'Shawn Levy': 3,
#  'Satish Rajwade': 3,
#  'Brett Haley': 3,
#  'Tom Hooper': 3,
#  'Toka McBaror': 3,
#  'Moses Inwang': 3,
#  'Vikas Bahl': 3,
#  'Neeraj Pandey': 3,
#  'Rako Prijanto': 3,
#  'Cem Yılmaz': 3,
#  'Ishaya Bako': 3,
#  'Olivier Assayas': 3,
#  'Pidi Baiq': 3,
#  'Michael McKay': 3,
#  'Ahmad El-Badri': 3,
#  'Lucas Margutti': 3,
#  'Seth Barrish': 3,
#  'Shirish Kunder': 3,
#  'Sermiyan Midyat': 3,
#  'Amr Arafa': 3,
#  'Ethan Coen': 3,
#  'Joel Coen': 3,
#  'Jon M. Chu': 3,
#  'Diego Pignataro': 3,
#  'Michael Dowse': 3,
#  'Mahesh Bhatt': 3,
#  'Prakash Mehra': 3,
#  'Jeff Baena': 3,
#  'Maria Ripoll': 3,
#  'Mark A.Z. Dippé': 3,
#  'Jon Rosenbaum': 3,
#  'Ron Oliver': 3,
#  'Abhishek Kapoor': 3,
#  'Michael Bay': 3,
#  'John Schultz': 3,
#  'Linda Mendoza': 3,
#  'Mikhail Red': 3,
#  'Pankaj Batra': 3,
#  'Abhishek Sharma': 3,
#  'Christopher Storer': 3,
#  'Neal Brennan': 3,
#  'David Michôd': 3,
#  'Craig Brewer': 3,
#  'Sujoy Ghosh': 3,
#  'John Asher': 3,
#  'Dante Lam': 3,
#  'Gonzalo López-Gallego': 3,
#  'Joe Berlinger': 3,
#  'Leena Yadav': 3,
#  'Hasan Karacadağ': 3,
#  'John Lee Hancock': 3,
#  'Olivia M. Lamasan': 3,
#  'Alex Lehmann': 3,
#  'Gastón Duprat': 3,
#  'Hiroyuki Seshita': 3,
#  'John Fortenberry': 3,
#  'Walter C. Miller': 3,
#  'Noriyuki Abe': 3,
#  'Alfonso Cuarón': 3,
#  'Andrew Lau Wai-Keung': 3,
#  'Nila Madhab Panda': 3,
#  'Timo Tjahjanto': 3,
#  'David Mackenzie': 3,
#  'Morgan Neville': 3,
#  'Raj Kumar Gupta': 3,
#  "Remo D'Souza": 3,
#  'Amitoj Mann': 3,
#  'Aziz Mirza': 3,
#  'Onir': 3,
#  'Bobcat Goldthwait': 3,
#  'Charles Stone III': 3,
#  'Latif Faiziyev': 3,
#  'Mike Flanagan': 3,
#  'Toshiyuki Kubooka': 3,
#  'Israel Adrián Caetano': 3,
#  'Lekh Tandon': 3,
#  'Edward Cotterill': 3,
#  'Ketan Mehta': 3,
#  'Ricky Gervais': 3,
#  'Werner Herzog': 3,
#  'Jonathan Demme': 3,
#  'Pratim D. Gupta': 3,
#  'Frank Coraci': 3,
#  'Roger Allers': 3,
#  'Karyn Kusama': 3,
#  'Peter Segal': 3,
#  'Adam Shankman': 3,
#  'Chandrakant Kulkarni': 3,
#  'Simon Wells': 3,
#  'Sumitra Bhave': 3,
#  'Sunil Sukthankar': 3,
#  'Ezekiel Norton': 3,
#  'Joe Camp': 3,
#  'Gajendra Ahire': 3,
#  'Raj Kapoor': 3,
#  'Vivieno Caldinelli': 3,
#  'Atom Egoyan': 3,
#  'Marc Forster': 3,
#  'Mohamed Samy': 3,
#  'Rob Cohen': 3,
#  'David R. Ellis': 3,
#  'Cheh Chang': 3,
#  'Kazuchika Kise': 3,
#  'Note Chern-Yim': 3,
#  'David Batty': 3,
#  'Barry Sonnenfeld': 3,
#  'Steve Sacks': 3,
#  'Dustin McKenzie': 3,
#  'Sylvester Stallone': 3,
#  'Vicky Matthews': 3,
#  'Frank Oz': 3,
#  'Joseph Sargent': 2,
#  'Hajime Kamegaki': 2,
#  'Kemi Adetiba': 2,
#  'Ridley Scott': 2,
#  'Neill Blomkamp': 2,
#  'Anthony Minghella': 2,
#  'Richard LaGravenese': 2,
#  'Jim Henson': 2,
#  'Sergio Leone': 2,
#  'Peter Spirer': 2,
#  'Randal Kleiser': 2,
#  'Tom Shadyac': 2,
#  'Malcolm D. Lee': 2,
#  'Sangeeth Sivan': 2,
#  'Apoorva Lakhia': 2,
#  'Charles Uwagbai': 2,
#  'Julián Hernández': 2,
#  'Alejandro Doria': 2,
#  'James Mangold': 2,
#  'Joe Roth': 2,
#  'Nick Castle': 2,
#  'Howard Zieff': 2,
#  'David Gordon Green': 2,
#  'Gary Ross': 2,
#  'Tony Scott': 2,
#  'Seyi Babatope': 2,
#  'Colin Trevorrow': 2,
#  'Bill Condon': 2,
#  'Kevin Munroe': 2,
#  'Hardik Mehta': 2,
#  'Vinil Mathew': 2,
#  'Ramsey Nouah': 2,
#  'Bong Joon Ho': 2,
#  'Mark Osborne': 2,
#  'Rob Marshall': 2,
#  'Stephen Frears': 2,
#  'Bryan Bertino': 2,
#  'Florian Henckel von Donnersmarck': 2,
#  'Måns Mårlind': 2,
#  'Björn Stein': 2,
#  'Robert O. Peters': 2,
#  'Jonathan Hensleigh': 2,
#  'Soudade Kaadan': 2,
#  'David O. Russell': 2,
#  'Peter Chelsom': 2,
#  'Bradley Parker': 2,
#  'Kenneth Gyang': 2,
#  'Mark Waters': 2,
#  'Jayan Moodley': 2,
#  'Daniel Benmayor': 2,
#  'James McTeigue': 2,
#  'Dominic Sena': 2,
#  'Barbra Streisand': 2,
#  'Michael Winterbottom': 2,
#  'Peter Hutchings': 2,
#  'Tim Johnson': 2,
#  'Zack Snyder': 2,
#  'J.D. Dillard': 2,
#  'Matthew Vaughn': 2,
#  'Aditya Kripalani': 2,
#  'David Pablos': 2,
#  'Alexandre Aja': 2,
#  'Baran bo Odar': 2,
#  'Ivan Ayr': 2,
#  'Justin Kelly': 2,
#  'Tom McGrath': 2,
#  'Jeff Wadlow': 2,
#  'Courtney Hunt': 2,
#  'Johannes Roberts': 2,
#  'John Wells': 2,
#  'Meltem Bozoflu': 2,
#  'Selçuk Aydemir': 2,
#  'Şenol Sönmez': 2,
#  'Satyajit Bhatkal': 2,
#  'Shashank Khaitan': 2,
#  'Justin Benson': 2,
#  'Aaron Moorhead': 2,
#  'Luis Valdez': 2,
#  'Park Hoon-jung': 2,
#  'BB Sasore': 2,
#  'Sylvie Verheyde': 2,
#  'Alex Zamm': 2,
#  'Ringo Lam': 2,
#  'Tony Giglio': 2,
#  'Shinji Aramaki': 2,
#  'Nelson McCormick': 2,
#  'Bejoy Nambiar': 2,
#  'John Hillcoat': 2,
#  'Kagiso Lediga': 2,
#  'Dimitri Logothetis': 2,
#  "Liam O'Donnell": 2,
#  'Walter Taylaur': 2,
#  'Chris Smith': 2,
#  'Muharrem Gülmez': 2,
#  'Mahsun Kırmızıgül': 2,
#  'Miguel Arteta': 2,
#  'Halitha Shameem': 2,
#  'Julien Leclercq': 2,
#  'Amy Poehler': 2,
#  'Mike Binder': 2,
#  'Emmett Malloy': 2,
#  'Liam Lynch': 2,
#  'John Erick Dowdle': 2,
#  'Alex Merkin': 2,
#  'Vikram Bhatt': 2,
#  'Damián Romay': 2,
#  'Michael Fimognari': 2,
#  'Esteban Crespo': 2,
#  'Sarah Gavron': 2,
#  'Jon Favreau': 2,
#  'Simon Stone': 2,
#  'Paul Haggis': 2,
#  'RZA': 2,
#  'Gary Fleder': 2,
#  'J.A. Bayona': 2,
#  'Darren Lynn Bousman': 2,
#  'Simon J. Smith': 2,
#  'James Toback': 2,
#  'Jeff Tremaine': 2,
#  'Brian Robbins': 2,
#  'Sean Penn': 2,
#  'Gore Verbinski': 2,
#  'George Clooney': 2,
#  'Kristian Mercado': 2,
#  'George C. Wolfe': 2,
#  'Brad Peyton': 2,
#  'Tom Ford': 2,
#  'Vir Das': 2,
#  'Ryan Murphy': 2,
#  'Girish Malik': 2,
#  'Jason Paul Laxamana': 2,
#  'Damien O’Connor': 2,
#  'Pierre Morel': 2,
#  'Bernie Denk': 2,
#  'Stanley Moore': 2,
#  'Alex Woo': 2,
#  'Brian Volk-Weiss': 2,
#  'Stephen Chiodo': 2,
#  'Kris Pearn': 2,
#  'David E. Talbert': 2,
#  'Paul Soriano': 2,
#  'Ryan Coogler': 2,
#  'Aitor Arregi': 2,
#  'Jon Garaño': 2,
#  'Ruel S. Bayani': 2,
#  'Chanda Bell': 2,
#  'Peter Berg': 2,
#  'Nicolas Pesce': 2,
#  'Olivier Marchal': 2,
#  'Chris Sivertson': 2,
#  'Kim Nguyen': 2,
#  'Ben Wheatley': 2,
#  'Ross Boyask': 2,
#  'Aaron Sorkin': 2,
#  'Keith Scholey': 2,
#  'Oz Rodriguez': 2,
#  'Taika Waititi': 2,
#  'Stacie Passon': 2,
#  'Dallas Jackson': 2,
#  'Rajat Kapoor': 2,
#  'Tsuyoshi Nakakuki': 2,
#  'Smeep Kang': 2,
#  'Tigmanshu Dhulia': 2,
#  'Chris Howe': 2,
#  'Makarand Mane': 2,
#  'Abba T. Makama': 2,
#  'Mark Steven Johnson': 2,
#  'Mark Thornton': 2,
#  'Todd Kauffman': 2,
#  'Wayne Blair': 2,
#  'Rebecca Zlotowski': 2,
#  'Tyler Spindel': 2,
#  'Peter Sullivan': 2,
#  'Daniel Oriahi': 2,
#  'Hannah Fidell': 2,
#  'Chris Renaud': 2,
#  "Anthony D'Souza": 2,
#  'Kabir Sadanand': 2,
#  'Umesh Shukla': 2,
#  'Luv Ranjan': 2,
#  'Shirley Frimpong-Manso': 2,
#  'Salvador Calvo': 2,
#  'Barry Avrich': 2,
#  'Bruce Beresford': 2,
#  'Paul Verhoeven': 2,
#  'Obi Emelonye': 2,
#  'David Dobkin': 2,
#  'Oluseyi Asurf': 2,
#  'Eduardo Roy Jr.': 2,
#  'Peter Lepeniotis': 2,
#  'Nicholas Kharkongor': 2,
#  'Ali F. Mostafa': 2,
#  'Sherif Arafa': 2,
#  'Michael Damian': 2,
#  'Ahmed Zain': 2,
#  'Ahmed Zein': 2,
#  'Alejandro Montiel': 2,
#  'Madeleine Parry': 2,
#  'Josh Safdie': 2,
#  'Benny Safdie': 2,
#  'Hiromasa Yonebayashi': 2,
#  'Yoshiyuki Momose': 2,
#  'Michael Showalter': 2,
#  'Alex Timbers': 2,
#  'Sam Wrench': 2,
#  'Ali Ragab': 2,
#  'Haifaa Al-Mansour': 2,
#  'Mohit Suri': 2,
#  'Claire Scanlon': 2,
#  'Vipul Amrutlal Shah': 2,
#  'Joe DeMaio': 2,
#  'Ashok Nanda': 2,
#  'Mysskin': 2,
#  'Dennie Gordon': 2,
#  'Bruno Garotti': 2,
#  'Hazem Fouda': 2,
#  'Upi Avianto': 2,
#  'Patryk Vega': 2,
#  'Ian Edelman': 2,
#  'M. Night Shyamalan': 2,
#  'Chris Robinson': 2,
#  'Yorgos Lanthimos': 2,
#  'Mukul Anand': 2,
#  'Tarun Mansukhani': 2,
#  'Punit Malhotra': 2,
#  'Shakun Batra': 2,
#  "Renzil D'Silva": 2,
#  'Àlex Pastor': 2,
#  'David Pastor': 2,
#  'Daniel Calparsoro': 2,
#  'Cristi Puiu': 2,
#  'Kunihiko Yuyama': 2,
#  'Jeethu Joseph': 2,
#  'Dee Rees': 2,
#  'Angelina Jolie': 2,
#  'Nate Adams': 2,
#  'Adam Carolla': 2,
#  'Erwin van den Eshof': 2,
#  'G.J. Echternkamp': 2,
#  'Ajay Bhuyan': 2,
#  'Tyler Perry': 2,
#  'Danny Boyle': 2,
#  'Paco Plaza': 2,
#  'Mikhil Musale': 2,
#  'Edwin': 2,
#  'Rhys Thomas': 2,
#  'David M. Rosenthal': 2,
#  'Fernando Meirelles': 2,
#  'Reema Kagti': 2,
#  'Trey Edward Shults': 2,
#  'Alexandre Avancini': 2,
#  'Navaniat Singh': 2,
#  'Luis Ara': 2,
#  'Steve Paley': 2,
#  'Eli Roth': 2,
#  'Shashanka Ghosh': 2,
#  'Naoko Yamada': 2,
#  'Harvey Lowry': 2,
#  'Zak Hilditch': 2,
#  'Gillian Robespierre': 2,
#  'Ciarán Foy': 2,
#  'Michael J. Bassett': 2,
#  'Scott Aukerman': 2,
#  'A. L. Vijay': 2,
#  'Alejandro Fernández Almendras': 2,
#  'Jota Linares': 2,
#  'Stan Lathan': 2,
#  'Tarsem Singh': 2,
#  'Demetri Martin': 2,
#  'Corey Yuen': 2,
#  'Aditya Sarpotdar': 2,
#  'Daniel Gray Longino': 2,
#  'Gerardo Olivares': 2,
#  'Spike Jonze': 2,
#  'Marcos Bucay': 2,
#  'Miguel Cohan': 2,
#  'Hideaki Anno': 2,
#  'Sanjay Jadhav': 2,
#  'Kyle Newacheck': 2,
#  'Federico Veiroj': 2,
#  'Francesco Imperato': 2,
#  'Herman Yau': 2,
#  'Ulises Valencia': 2,
#  'Suparn Verma': 2,
#  'Swapnaneel Jayakar': 2,
#  'Javier Ruiz Caldera': 2,
#  'Joyce Bernal': 2,
#  'Maryo J. De los Reyes': 2,
#  'Amy Schumer': 2,
#  'J.C. Chandor': 2,
#  'Ibrahim Bin Mohamed': 2,
#  'Clark Johnson': 2,
#  'Keoni Waxman': 2,
#  'Sridhar Rangayan': 2,
#  'Mar Targarona': 2,
#  'Parambrata Chatterjee': 2,
#  'Kevin MacDonald': 2,
#  'Marcelo Galvão': 2,
#  'Tanuja Chandra': 2,
#  'Michael D. Black': 2,
#  'Dan Gilroy': 2,
#  'Zoe Berriatúa': 2,
#  'Jerrold Tarog': 2,
#  'Matías Gueilburt': 2,
#  'Kobun Shizuno': 2,
#  'Kunal Kohli': 2,
#  'Terry Jones': 2,
#  'Chris Bould': 2,
#  'Sriram Raghavan': 2,
#  'Michael Cuesta': 2,
#  'Baljit Singh Deo': 2,
#  'Raditya Dika': 2,
#  'David Paul Meyer': 2,
#  'Ksshitij Chaudhary': 2,
#  'Sundar C.': 2,
#  'Nikhil Advani': 2,
#  'Kevin Layne': 2,
#  'Thiru': 2,
#  'Gareth Evans': 2,
#  'Rizal Mantovani': 2,
#  'Rusty Cundieff': 2,
#  'Eric Idle': 2,
#  'Ian MacNaughton': 2,
#  'N. Linguswamy': 2,
#  'Joram Lürsen': 2,
#  'Shivam Nair': 2,
#  'Susan Johnson': 2,
#  'Nitesh Tiwari': 2,
#  'Ted Emery': 2,
#  'Scott Zabielski': 2,
#  'Scott L. Montoya': 2,
#  'Shlok Sharma': 2,
#  'Jeffrey Walker': 2,
#  'Andrew Niccol': 2,
#  'Sang-ho Yeon': 2,
#  'Andy Fickman': 2,
#  'Peter Orton': 2,
#  'Duncan Jones': 2,
#  'Ari Sandel': 2,
#  'Scott Moran': 2,
#  'Patrick Brice': 2,
#  'Jacob Kornbluth': 2,
#  'Errol Morris': 2,
#  'Griffin Dunne': 2,
#  'Shakti Samanta': 2,
#  'Karen J. Lloyd': 2,
#  'Warren P. Sonoda': 2,
#  'Álex de la Iglesia': 2,
#  'Eli Craig': 2,
#  'Mariano Cohn': 2,
#  'Sarah Adina Smith': 2,
#  'S.S. Rajamouli': 2,
#  "Bill D'Elia": 2,
#  'Cal Seville': 2,
#  'Jalil Lespert': 2,
#  'Sean Cisterna': 2,
#  'Steven Brill': 2,
#  'Antonio Serrano': 2,
#  'Charlie McDowell': 2,
#  'Santosh Sivan': 2,
#  'Erik Canuel': 2,
#  'Mike Birbiglia': 2,
#  'Akiva Schaffer': 2,
#  'Alistair Legrand': 2,
#  'Mitch Schauer': 2,
#  'James Yukich': 2,
#  'Osgood Perkins': 2,
#  'Dave Higby': 2,
#  'Michael Drumm': 2,
#  'Anu Menon': 2,
#  'Byron Howard': 2,
#  'Fisher Stevens': 2,
#  'Joe Dante': 2,
#  'Atanu Ghosh': 2,
#  'Daniel Stamm': 2,
#  'Jon Lucas': 2,
#  'Scott Moore': 2,
#  'Hani Hamdi': 2,
#  'Ruben Fleischer': 2,
#  'Jack C. Newell': 2,
#  'Jonathan Levine': 2,
#  'Toa Fraser': 2,
#  'Padmakumar Narasimhamurthy': 2,
#  'Stanley Kubrick': 2,
#  'Asghar Farhadi': 2,
#  'Chad Van De Keere': 2,
#  'Nicolás López': 2,
#  'Don Bluth': 2,
#  'Richard Rich': 2,
#  'Sam Mendes': 2,
#  'Asif Kapadia': 2,
#  'Larry Latham': 2,
#  'Ismail Farouk': 2,
#  'Manish Jha': 2,
#  'Khaled El Halafawy': 2,
#  'Nia Dinata': 2,
#  'Mez Tharatorn': 2,
#  'Phil Weinstein': 2,
#  'Michael Goguen': 2,
#  'Esteban Vidal': 2,
#  'Dharmesh Darshan': 2,
#  'Nick Broomfield': 2,
#  'Stephen Daldry': 2,
#  'Daniel Alfredson': 2,
#  'Ted Demme': 2,
#  'Derek Cianfrance': 2,
#  'Rian Johnson': 2,
#  'Daniel Mann': 2,
#  'Chito S. Roño': 2,
#  'Brian De Palma': 2,
#  'Pete Travis': 2,
#  'Gilles Paquet-Brenner': 2,
#  'Ken Burns': 2,
#  'Christopher Smith': 2,
#  'Jared Hess': 2,
#  'Greg MacGillivray': 2,
#  'Will Gluck': 2,
#  'Philipp Stölzl': 2,
#  'Nagraj Manjule': 2,
#  'Norman Jewison': 2,
#  'James Wong': 2,
#  'Mahmoud Karim': 2,
#  'Ifa Isfansyah': 2,
#  'Rudy Soedjarwo': 2,
#  'Harold Cronk': 2,
#  'Robert Altman': 2,
#  'Ali Taner Baltacı': 2,
#  'Satish Kaushik': 2,
#  'Timothy Woodward Jr.': 2,
#  'Anthony Scott Burns': 2,
#  'Bille Woodruff': 2,
#  'Janusz Majewski': 2,
#  'Jonathan Mostow': 2,
#  'Matt Kugelman': 2,
#  'Benjamin Turner': 2,
#  'Sachin': 2,
#  'Brad Bird': 2,
#  'Patricia Rozema': 2,
#  'Kedar Shinde': 2,
#  'Leo Riley': 2,
#  'Tim Story': 2,
#  'John Stockwell': 2,
#  'Frank Capra': 2,
#  'Alex Proyas': 2,
#  'Stephen Chow': 2,
#  'Stanley Tong': 2,
#  'R. Ellis Frazier': 2,
#  'Ron Myrick': 2,
#  'John Huston': 2,
#  'Guy Ritchie': 2,
#  'Sze Yu Lau': 2,
#  'Luc Vinciguerra': 2,
#  'Sameer Vidwans': 2,
#  'Eric Radomski': 2,
#  'Sudesh Manjrekar': 2,
#  'Gus Van Sant': 2,
#  'Kenny Young': 2,
#  'Brett Ratner': 2,
#  'Audu Paden': 2,
#  'Avadhoot Gupte': 2,
#  'James Bobin': 2,
#  'Lewis Milestone': 2,
#  'Jayson Thiessen': 2,
#  'Tim Maltby': 2,
#  'Oliver Twinch': 2,
#  'Lars von Trier': 2,
#  'Charlie Lightening': 2,
#  'Mark Palansky': 2,
#  'Parkpoom Wongpoom': 2,
#  'Basu Chatterjee': 2,
#  'John Dahl': 2,
#  'Mohamed Hamdy': 2,
#  'Dino Risi': 2,
#  'Wes Craven': 2,
#  'Kasia Uscinska': 2,
#  'Susannah Ward': 2,
#  'Sam Taplin': 2,
#  'Michael Patrick King': 2,
#  'Richard Bailey': 2,
#  'Sam Raimi': 2,
#  'William Brent Bell': 2,
#  'Neil Jordan': 2,
#  'Tarek Al Eryan': 2,
#  'Paul Andrew Williams': 2,
#  'James Ponsoldt': 2,
#  'Rodrigo Van Der Put': 2,
#  'Isaac Ezban': 2,
#  'Femi Oyeniran': 2,
#  'Robin Swicord': 2,
#  'Alejandro Agresti': 2,
#  'Stanisław Różewicz': 2,
#  'John Duigan': 2,
#  'Hadi El Bagoury': 2,
#  'Jason Reitman': 2,
#  'Saratswadee Wongsomphet': 2,
#  'Haile Gerima': 1,
#  'Theodore Melfi': 1,
#  'Christian Schwochow': 1,
#  'S. Shankar': 1,
#  'George Nolfi': 1,
#  'Jeannot Szwarc': 1,
#  'Joe Alves': 1,
#  'Daniel Espinosa': 1,
#  'Hirotsugu Kawasaki': 1,
#  'Toshiyuki Tsuru': 1,
#  'Tensai Okamura': 1,
#  'Cedric Nicolas-Troyan': 1,
#  'JJC Skillz': 1,
#  'Funke Akindele': 1,
#  'Alice Waddington': 1,
#  'Stephen Kijak': 1,
#  'Lijo Jose Pellissery': 1,
#  'David de Vos': 1,
#  'Rahul Rawail': 1,
#  'Shanker Raman': 1,
#  'Vidhu Vinod Chopra': 1,
#  'Mark Rosman': 1,
#  'George Jackson': 1,
#  'Doug McHenry': 1,
#  'Eric Meza': 1,
#  'Michael Martin': 1,
#  'Michael Rymer': 1,
#  'Andrew Lau Wai-keung': 1,
#  'Alan Mak': 1,
#  'Brett Weiner': 1,
#  'Gary Winick': 1,
#  'Danishka Esterhazy': 1,
#  'Troy Byer': 1,
#  'Kinka Usher': 1,
#  "Matthew O'Callaghan": 1,
#  'Todd Wilderman': 1,
#  'Michael Carney': 1,
#  'Richard Linklater': 1,
#  'Amy Rice': 1,
#  'Michael Ritchie': 1,
#  'J. Lee Thompson': 1,
#  'Evan Goldberg': 1,
#  'Seth Rogen': 1,
#  'Ramzy Bedia': 1,
#  'Éric Judor': 1,
#  'Sharan Koppisetty': 1,
#  'Taylor Sheridan': 1,
#  'Saurabh Kabra': 1,
#  'Partho Mitra': 1,
#  'Santram Varma': 1,
#  'Anil V. Kumar': 1,
#  'Umesh Ghadge': 1,
#  'Pawan Kripalani': 1,
#  'Bhushan Patel': 1,
#  'Raj Nidimoru': 1,
#  'Krishna D.K.': 1,
#  'Angel Kristi Williams': 1,
#  'Christopher Alender': 1,
#  'David Oyelowo': 1,
#  'Brian Andrew Mendoza': 1,
#  'Paakhi Tyrewala': 1,
#  'Ferdinando Cito Filomarino': 1,
#  'Julián Gaviria': 1,
#  'Steven Yamamoto': 1,
#  'Jonathan Teplitzky': 1,
#  'Dustin Hoffman': 1,
#  'Quoc Bao Tran': 1,
#  'Just Philippot': 1,
#  'Kirk DeMicco': 1,
#  'Brandon Jeffords': 1,
#  'Laura Fairrie': 1,
#  'Marcelo Piñeyro': 1,
#  'Izu Ojukwu': 1,
#  'Peter Winther': 1,
#  'Susan Lacy': 1,
#  'Chineze Anyaene': 1,
#  'Rod Daniel': 1,
#  'Todor Chapkanov': 1,
#  'Phil Lord': 1,
#  'Christopher Miller': 1,
#  'John Hughes': 1,
#  'Justin Baldoni': 1,
#  'Mark Helfrich': 1,
#  'Christopher Nolan': 1,
#  'David Feiss': 1,
#  'Jorge Blanco': 1,
#  'Zara Hayes': 1,
#  'Trey Parker': 1,
#  'Kelly Fremon Craig': 1,
#  'Tom Elkins': 1,
#  'Brad Furman': 1,
#  'Sylvain White': 1,
#  'Irwin Winkler': 1,
#  'Najwa Najjar': 1,
#  'Michelle Bello': 1,
#  'Daniel Markowicz': 1,
#  'Yuval Adler': 1,
#  'Augustine Frizzell': 1,
#  'Ainsley Gardiner': 1,
#  'Briar Grace-Smith': 1,
#  'Morgan Ingari': 1,
#  'Abdulaziz Alshlahei': 1,
#  'Edward Drake': 1,
#  'Sita Likitvanichkul': 1,
#  'Jetarin Ratanaserikiat': 1,
#  'Apirak Samudkitpaisan': 1,
#  'Thanabodee Uawithya': 1,
#  'Adirek Wattaleela': 1,
#  'David Slade': 1,
#  'Catherine Hardwicke': 1,
#  'Hadrah Daeng Ratu': 1,
#  'Ash Brannon': 1,
#  'Roberto De Feo': 1,
#  'Paolo Strippoli': 1,
#  'Semi Chellas': 1,
#  'Nima Nourizadeh': 1,
#  'Jericca Cleland': 1,
#  'Ahmed Siddiqui': 1,
#  'Hallie Meyers-Shyer': 1,
#  'Scott Speer': 1,
#  'Camille Delamarre': 1,
#  'Mahmood Ali-Balogun': 1,
#  'Christine Luby': 1,
#  'Yeo Siew Hua': 1,
#  'Rajveer Singh Maan': 1,
#  'Harpeet Singh': 1,
#  'Saw Teong Hin': 1,
#  'Nik Amir Mustapha': 1,
#  'M.S. Prem Nath': 1,
#  'Pramod Pawar': 1,
#  'Naresh Saigal': 1,
#  'Kim Tae-hyung': 1,
#  'Michael Spierig': 1,
#  'Peter Spierig': 1,
#  'Frank Marshall': 1,
#  'Victor Vu': 1,
#  'Joel Hopkins': 1,
#  'John Stevenson': 1,
#  'Jennifer Yuh Nelson': 1,
#  'Greg Berlanti': 1,
#  'Garth Davis': 1,
#  'Martin Brest': 1,
#  'Joel Gallen': 1,
#  'Claire McCarthy': 1,
#  'Trevor Nunn': 1,
#  'Jim Field Smith': 1,
#  'Chris Koch': 1,
#  'J.J. Abrams': 1,
#  'Anton Corbijn': 1,
#  'Robin Bissell': 1,
#  'Alan Parker': 1,
#  'Phil Alden Robinson': 1,
#  'Len Wiseman': 1,
#  'Patrick Tatopoulos': 1,
#  'Vincent Ward': 1,
#  'Gregory Nava': 1,
#  'Matt Thompson': 1,
#  'Matt Aselton': 1,
#  'Andrew Dominik': 1,
#  'Anissa Bonnefont': 1,
#  'Bahij Hojeij': 1,
#  'Justin P. Lange': 1,
#  'Jayme Monjardim': 1,
#  'Kingsley Ogoro': 1,
#  'Marie Clements': 1,
#  'Max Jabs': 1,
#  ...}
